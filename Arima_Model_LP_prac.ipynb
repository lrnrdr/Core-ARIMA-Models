# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.tsa.api as tsa
from pmdarima.model_selection import train_test_split
from pmdarima.arima.utils import ndiffs

# %%
# Custom function for Ad Fuller Test
def get_adfuller_results(ts, alpha=.05, label='adfuller', **kwargs): #kwargs for adfuller()
    # Saving each output
    (test_stat, pval, nlags, nobs, crit_vals_d, 
    icbest ) = tsa.adfuller(ts, **kwargs)
    # Converting output to a dictionary with the interpretation of p
    adfuller_results = {'Test Statistic': test_stat,
                        "# of Lags Used":nlags, 
                       '# of Observations':nobs,
                        'p-value': round(pval,6),
                        'alpha': alpha,
                       'sig/stationary?': pval < alpha}
    return pd.DataFrame(adfuller_results, index =[label])

# %%
# Load in data
ts = pd.read_csv('AR_lesson_ts.csv', index_col = 'date')
ts.head()
# Out:
#              dollars
# date
# 2020-01-05  0.422207
# 2020-01-12 -0.455290
# 2020-01-19  0.914767
# 2020-01-26  0.562761
# 2020-02-02 -0.649239

# %%
#Make the data into a time series with the index as a DateTime object with a weekly frequency

# Make index datetime
ts.index = pd.to_datetime(ts.index)
# We have weekly data so we will set our frequency to W
ts.index.freq= "W"
# Make a series
ts = ts['dollars']

# %%
# Check for null values
ts.isna().sum().sum()
# Out:
# 0

# %%
# Plot the time series
ts.plot();

# %% [markdown]
# ![image.png](attachment:32bbc584-920d-4091-83e1-d85bcdcf436d.png)

# %%
# Make acf plot of raw data to look for seasonality
tsa.graphics.plot_acf(ts);

# %% [markdown]
# ![image.png](attachment:7042824b-27cf-49dd-b28e-c7d0eabd2cee.png)

# %%
# Call custom function to check to see if data is stationary
get_adfuller_results(ts)
# Out:
#           Test Statistic  # of Lags Used  # of Observations  p-value  alpha  \
# adfuller      -14.612186               1                198      0.0   0.05
#
#           sig/stationary?
# adfuller             True

# %% [markdown]
# ![image.png](attachment:261fc270-0862-49e8-9f24-4e30ab76485e.png)

# %%
from pmdarima.arima.utils import ndiffs
# use ndiffs to determine differencing
d = ndiffs(ts)
print(f'd is {d}')
# Out:
# d is 0

# %% [markdown]
# ![image.png](attachment:e3a3ab49-39e1-4ddc-ac24-79ab0ea3a1db.png)

# %%
# Make acf plot to determine if this is AR or MA 
tsa.graphics.plot_acf(ts);

# %% [markdown]
# ![image.png](attachment:596b2f89-0e04-43fa-8b4e-f1ca552f104d.png)

# %% [markdown]
# ## In the above example shows a gradual decrease in the magnitude of the value.
# -
# When we see this in our ACF, plot, it indicates that an auto-regressive (AR) model will likely be appropriate.

# %% [markdown]
# ___

# %% [markdown]
# ![image.png](attachment:efb0d8cd-99ae-4cc0-9901-5ad806d90c8f.png)

# %%
# Examine the PACF plot to determine order of AR model
tsa.graphics.plot_pacf(ts);

# %% [markdown]
# ![image.png](attachment:b5f6e563-0bcd-448c-9f1d-af7c31daf283.png)

# %% [markdown]
# # The PACF plot above shows a very abrupt drop after lag 1.
# - This indicates that we only need one coefficient in our AR model, known as an AR(1) model. The number of coefficients in an AR model is p, so in this case, p = 1.

# %% [markdown]
# ![image.png](attachment:ce8fc72c-a7d1-4089-b1f7-2f5ad14a40b0.png)

# %% [markdown]
# ![image.png](attachment:bc51d6aa-2d56-44ab-96c1-523689c0f738.png)

# %%
from pmdarima.model_selection import train_test_split
# tts
train, test = train_test_split(ts, test_size=.20)
# Visualize the train and test data
ax = train.plot(label='Train')
test.plot(ax=ax, label='Test')
ax.legend();

# %% [markdown]
# ![image.png](attachment:4c1c395c-f1a8-4824-b5d3-045bdb40ed1e.png)

# %%
# proper way to import tsa submodule
import statsmodels.tsa.api as tsa

# %% [markdown]
# ![image.png](attachment:c25b6571-e13c-46ee-a496-5659018805fc.png)

# %%
# First define the orders (p,d,q)
p = 1 # AR(1) model based on significant lags in PACF
d = 0 # No differcing needed to make stationary
q = 0 # q will be used for MA models (set to 0 for an AR only model)
# Now instantiate the model with the data and fit
ar_1_model = tsa.ARIMA(train, order = (p,d,q)).fit()
ar_1_model

# %% [markdown]
# ![image.png](attachment:d320f8f7-b31b-4b3d-8bf6-bae9ad9fa174.png)

# %%
# Obtain the parameters of the fit model
ar_1_model.params
# Out:
# const    -0.033178
# ar.L1    -0.754862
# sigma2    0.626342
# dtype: float64

# %% [markdown]
# ![image.png](attachment:0f82a275-48d6-4ba1-b507-0eaaf4a6d700.png)

# %%
# Obtain forecast as a dataframe with confidence intervals
forecast_df = ar_1_model.get_forecast(steps=len(test)).summary_frame()
forecast_df.head()
# Out:
# dollars         mean   mean_se  mean_ci_lower  mean_ci_upper
# 2023-01-29 -0.600555  0.791418      -2.151706       0.950595
# 2023-02-05  0.395113  0.991585      -1.548359       2.338585
# 2023-02-12 -0.356479  1.089316      -2.491499       1.778541
# 2023-02-19  0.210869  1.141267      -2.025974       2.447712
# 2023-02-26 -0.217400  1.169839      -2.510242       2.075441

# %% [markdown]
# ![image.png](attachment:17a2f36d-9b6a-40d6-a59f-30bdae487481.png)

# %%
def plot_forecast(ts_train, ts_test, forecast_df, n_train_lags=None, 
                  figsize=(10,4), title='Comparing Forecast vs. True Data'):
    ### PLot training data, and forecast (with upper/,lower ci)
    fig, ax = plt.subplots(figsize=figsize)
    # setting the number of train lags to plot if not specified
    if n_train_lags==None:
        n_train_lags = len(ts_train)
            
    # Plotting Training  and test data
    ts_train.iloc[-n_train_lags:].plot(ax=ax, label="train")
    ts_test.plot(label="test", ax=ax)
    # Plot forecast
    forecast_df['mean'].plot(ax=ax, color='green', label="forecast")
    # Add the shaded confidence interval
    ax.fill_between(forecast_df.index, 
                    forecast_df['mean_ci_lower'],
                   forecast_df['mean_ci_upper'],
                   color='green', alpha=0.3,  lw=2)
    # set the title and add legend
    ax.set_title(title)
    ax.legend();
    
    return fig, ax

# %%
# Call the custom function to plot the forecasts with confidence intervals and true values
plot_forecast(train, test, forecast_df);

# %% [markdown]
# ![image.png](attachment:2c4b1a57-13df-4e0b-8eac-9eff7458306f.png)

# %% [markdown]
# ![image.png](attachment:098d3dc6-9b61-42ca-9c22-78accf0f8b4d.png)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

def regression_metrics_ts(ts_true, ts_pred, label="", verbose=True, output_dict=False,):
    # Get metrics
    mae = mean_absolute_error(ts_true, ts_pred)
    mse = mean_squared_error(ts_true, ts_pred)
    rmse = mean_squared_error(ts_true, ts_pred, squared=False)
    r_squared = r2_score(ts_true, ts_pred)
    mae_perc = mean_absolute_percentage_error(ts_true, ts_pred) * 100

    if verbose == True:
        # Print Result with label
        header = "---" * 20
        print(header, f"Regression Metrics: {label}", header, sep="\n")
        print(f"- MAE = {mae:,.3f}")
        print(f"- MSE = {mse:,.3f}")
        print(f"- RMSE = {rmse:,.3f}")
        print(f"- R^2 = {r_squared:,.3f}")
        print(f"- MAPE = {mae_perc:,.2f}%")

    if output_dict == True:
        metrics = {
            "Label": label,
            "MAE": mae,
            "MSE": mse,
            "RMSE": rmse,
            "R^2": r_squared,
            "MAPE(%)": mae_perc,
        }
        return metrics

# %%
# Now, we will call our updated function:
# Obtain metrics
regression_metrics_ts(test, forecast_df['mean'])
# Out:
# ------------------------------------------------------------
# Regression Metrics:
# ------------------------------------------------------------
# - MAE = 0.905
# - MSE = 1.354
# - RMSE = 1.164
# - R^2 = 0.035
# - MAPE = 120.08%

# %% [markdown]
# ![image.png](attachment:92ed7044-73aa-45bd-9f70-64f4fe6fb356.png)
